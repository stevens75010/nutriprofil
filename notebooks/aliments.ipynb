# %%
import pandas as pd

# %%
aliment = pd.read_csv("../datasets/composition/DF_Aliment_NUTRIPROFIL.csv", nrows=100)
#aliment['Famille_regroupee'].unique()
aliment
# Out:
#                                               Aliment  Calories  Fibres  \
# 0                                              Pastis     274.0    0.00
# 1                                     Bigorneau, cuit      85.0    0.00
# 2                  Calmar ou calamar ou encornet, cru      77.0    0.00
# 3   Calmar ou Calamar ou encornet, é la romaine (b...     252.0    1.66
# 4        Coquille Saint-Jacques, noix et corail, crue      83.0    0.00
# ..                                                ...       ...     ...
# 95                    Levure de boulanger, compressée     100.0    7.15
# 96                                           Moutarde     152.0    1.00
# 97                                      Persil, frais      43.0    4.30
# 98                                Poivre noir, poudre     330.0   25.70
# 99                                       Raifort, cru     100.0    7.50
#
#     Glucides   Gras    IG    CG  Proteines Famille_regroupee
# ...
