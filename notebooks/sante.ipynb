# %%
import pandas as pd

# %%
risques = pd.read_csv("../datasets/sante/cohorte_seuils_risques.csv")

risques
# Out:
#   var_nutrition     seuil                    maladie risque_relatif  \
# 0      procmeat    50 g/j  mortalité (toutes causes)           +18%
# 1          ssbs  100 ml/j        cancer (tous types)           +18%
# 2        sodium    >2 g/j               hypertension     +20 à +30%
# 3         fiber   +10 g/j             diabète type 2            -9%
# 4       redmeat   100 g/j          cancer colorectal           +12%
# 5         fruit    80 g/j                        MCV            -4%
#
#                                       interpretation         source_cohorte  \
# 0  +18% de mortalité par 50g/j de viande transformée            EPIC (2013)
# 1  +18% de cancer global par 100ml/j de boissons ...  NutriNet-Santé (2019)
# 2            +20–30% de risque d’HTA si sodium >2g/j   Nurses’ Health Study
# 3  -9% de risque de diabète type 2 par 10g/j de f...            EPIC (2015)
# 4  +12% de risque de cancer colorectal par 100g/j...            EPIC (2011)
# ...

# %%
sante = pd.read_csv("../datasets/sante/france_nutrition_sante_risque.csv")

sante
# Out:
#      year_id age_group_name sex_name  wholegrains         veg  transfat  \
# 0       1990       25 to 29   Female     7.708199  160.882840  0.591138
# 1       1990       30 to 34   Female     8.481469  164.792356  0.581463
# 2       1990       35 to 39   Female     9.188756  168.020758  0.591546
# 3       1990       40 to 44   Female     9.676013  168.939242  0.602664
# 4       1990       45 to 49   Female     9.942808  177.671908  0.606757
# ..       ...            ...      ...          ...         ...       ...
# 115     1993       75 to 79     Male     8.827057  146.955412  0.687179
# 116     1993       80 to 84     Male     8.864249  130.137394  0.712886
# 117     1993       85 to 89     Male    11.595627  136.024749  0.711508
# 118     1993       90 to 94     Male     9.558843  137.625092  0.711086
# 119     1993        95 plus     Male     9.356401  137.031249  0.715220
#
#       procmeat    sodium        ssbs      nuts  ...  ssbs_over_seuil  \
# ...
